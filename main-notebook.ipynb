# %%
import stylegan_two
from stylegan_two import StyleGAN

# %%
stylegan_two.directory = "data/img_align_celeba/"
stylegan_two.BATCH_SIZE = 16

# %%
from datagen import dataGenerator

# %%
gen = dataGenerator(stylegan_two.directory, 512, 16)
# Out:
# 202599 images found

# %%
model = StyleGAN(lr = 0.0001, silent = False)
model.evaluate(0)

while model.GAN.steps < 1000:
    model.train()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1536)         3072        lambda[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 4, 4, 96)     0           dense_5[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4, 4, 96)     0           reshape[0][0]
# ...
