# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import stylegan_two
from stylegan_two import StyleGAN

# %%
image_paths_a = tf.data.Dataset.list_files("data/safedere-faces-512/*.jpg")
image_paths_r = tf.data.Dataset.list_files("data/ffhq-512/*.jpg")
image_paths_a = image_paths_a.repeat()
image_paths_r = image_paths_r.repeat()
def data_gen():
    for a,b in tf.data.Dataset.zip((image_paths_a,image_paths_r)) :
        yield a
        yield b
dataset = tf.data.Dataset.from_generator(data_gen, tf.string)

# %%
stylegan_two.im_size = 256
stylegan_two.BATCH_SIZE = 8
stylegan_two.dataset = dataset

# %%
model = StyleGAN(lr = 0.0001, silent = False)
model.evaluate(0)

# %%
while model.GAN.steps < 1000000:
    model.train()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 512)]        0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 1)            0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1536)         3072        lambda[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 4, 4, 96)     0           dense_5[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4, 4, 96)     0           reshape[0][0]
# ...
